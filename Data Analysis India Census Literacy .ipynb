# %% [markdown]
# # Data Analysis Project

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the data file

# %%
df = pd.read_csv("C:/Users/win10/Desktop/India Census 2011 Tables/India_Literacy.csv")

# %%
df
# Out:
#                       State_name              District_name  Literate  \
# 0              JAMMU AND KASHMIR                    Kupwara    439654
# 1              JAMMU AND KASHMIR                     Badgam    335649
# 2              JAMMU AND KASHMIR                Leh(Ladakh)     93770
# 3              JAMMU AND KASHMIR                     Kargil     86236
# 4              JAMMU AND KASHMIR                      Punch    261724
# ..                           ...                        ...       ...
# 635                  PONDICHERRY                       Mahe     36470
# 636                  PONDICHERRY                   Karaikal    154916
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     25332
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman     78683
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman    190266
#
#      Female_Literate  Male_Literate  Population  Graduate_Education  \
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of                       State_name              District_name  Literate  \
# 0              JAMMU AND KASHMIR                    Kupwara    439654
# 1              JAMMU AND KASHMIR                     Badgam    335649
# 2              JAMMU AND KASHMIR                Leh(Ladakh)     93770
# 3              JAMMU AND KASHMIR                     Kargil     86236
# 4              JAMMU AND KASHMIR                      Punch    261724
# ..                           ...                        ...       ...
# 635                  PONDICHERRY                       Mahe     36470
# 636                  PONDICHERRY                   Karaikal    154916
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     25332
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman     78683
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman    190266
#
#      Female_Literate  Male_Literate  Population  Graduate_Education  \
# ...

# %%
df.describe()
# Out:
#            Literate  Female_Literate  Male_Literate    Population  \
# count  6.400000e+02     6.400000e+02   6.400000e+02  6.400000e+02
# mean   1.193186e+06     5.138675e+05   6.793182e+05  1.891961e+06
# std    1.068583e+06     4.801816e+05   5.924144e+05  1.544380e+06
# min    4.436000e+03     1.822000e+03   2.614000e+03  8.004000e+03
# 25%    4.825982e+05     2.008920e+05   2.764365e+05  8.178610e+05
# 50%    9.573465e+05     4.038590e+05   5.483525e+05  1.557367e+06
# 75%    1.602260e+06     6.641550e+05   9.188582e+05  2.583551e+06
# max    8.227161e+06     3.635765e+06   4.591396e+06  1.106015e+07
#
#        Graduate_Education  Illiterate_Education
# count        6.400000e+02          6.400000e+02
# mean         1.090132e+05          5.786784e+05
# std          1.502260e+05          4.887864e+05
# min          3.560000e+02          2.185000e+03
# 25%          2.799200e+04          2.142040e+05
# 50%          6.624350e+04          4.529330e+05
# ...

# %% [markdown]
# # Population histogram graph

# %%
sns.distplot(df['Population'])
# Out:
# <AxesSubplot: xlabel='Population', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['State_name', 'District_name', 'Literate', 'Female_Literate',
#        'Male_Literate', 'Population', 'Graduate_Education',
#        'Illiterate_Education'],
#       dtype='object')

# %%
columns = ['Literate', 'Female_Literate','Male_Literate', 'Population', 'Graduate_Education','Illiterate_Education']
for i in columns:
    plt.figure()
    sns.distplot(df[i])

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                       State_name              District_name  Literate  \
# 0              JAMMU AND KASHMIR                    Kupwara    439654
# 1              JAMMU AND KASHMIR                     Badgam    335649
# 2              JAMMU AND KASHMIR                Leh(Ladakh)     93770
# 3              JAMMU AND KASHMIR                     Kargil     86236
# 4              JAMMU AND KASHMIR                      Punch    261724
# ..                           ...                        ...       ...
# 635                  PONDICHERRY                       Mahe     36470
# 636                  PONDICHERRY                   Karaikal    154916
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     25332
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman     78683
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman    190266
#
#      Female_Literate  Male_Literate  Population  Graduate_Education  \
# ...

# %%
sns.kdeplot(df['Population'],shade=True);

# %%
df
# Out:
#                       State_name              District_name  Literate  \
# 0              JAMMU AND KASHMIR                    Kupwara    439654
# 1              JAMMU AND KASHMIR                     Badgam    335649
# 2              JAMMU AND KASHMIR                Leh(Ladakh)     93770
# 3              JAMMU AND KASHMIR                     Kargil     86236
# 4              JAMMU AND KASHMIR                      Punch    261724
# ..                           ...                        ...       ...
# 635                  PONDICHERRY                       Mahe     36470
# 636                  PONDICHERRY                   Karaikal    154916
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     25332
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman     78683
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman    190266
#
#      Female_Literate  Male_Literate  Population  Graduate_Education  \
# ...

# %%
df.sum()
# Out:
# State_name              JAMMU AND KASHMIRJAMMU AND KASHMIRJAMMU AND KA...
# District_name           KupwaraBadgamLeh(Ladakh)KargilPunchRajouriKath...
# Literate                                                        763638812
# Female_Literate                                                 328875190
# Male_Literate                                                   434763622
# Population                                                     1210854977
# Graduate_Education                                               69768429
# Illiterate_Education                                            370354195
# dtype: object

# %%
df.mean()
# Out:
# Literate                1.193186e+06
# Female_Literate         5.138675e+05
# Male_Literate           6.793182e+05
# Population              1.891961e+06
# Graduate_Education      1.090132e+05
# Illiterate_Education    5.786784e+05
# dtype: float64

# %%
df.dtypes
# Out:
# State_name              object
# District_name           object
# Literate                 int64
# Female_Literate          int64
# Male_Literate            int64
# Population               int64
# Graduate_Education       int64
# Illiterate_Education     int64
# dtype: object

# %%
df.count()
# Out:
# State_name              640
# District_name           640
# Literate                640
# Female_Literate         640
# Male_Literate           640
# Population              640
# Graduate_Education      640
# Illiterate_Education    640
# dtype: int64

# %%
df.min()
# Out:
# State_name              ANDAMAN AND NICOBAR ISLANDS
# District_name                              Adilabad
# Literate                                       4436
# Female_Literate                                1822
# Male_Literate                                  2614
# Population                                     8004
# Graduate_Education                              356
# Illiterate_Education                           2185
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State_name            640 non-null    object
#  1   District_name         640 non-null    object
#  2   Literate              640 non-null    int64
#  3   Female_Literate       640 non-null    int64
#  4   Male_Literate         640 non-null    int64
#  5   Population            640 non-null    int64
#  6   Graduate_Education    640 non-null    int64
#  7   Illiterate_Education  640 non-null    int64
# dtypes: int64(6), object(2)
# memory usage: 40.1+ KB

# %%
df.shape
# Out:
# (640, 8)

# %%
df.size
# Out:
# 5120

# %%
df.index
# Out:
# RangeIndex(start=0, stop=640, step=1)

# %%
df.iloc[0]
# Out:
# State_name              JAMMU AND KASHMIR
# District_name                     Kupwara
# Literate                           439654
# Female_Literate                    156831
# Male_Literate                      282823
# Population                         870354
# Graduate_Education                  21751
# Illiterate_Education               289765
# Name: 0, dtype: object

# %%
df.plot(kind='scatter',x='State_name',y='Population',figsize=(6,6))
# Out:
# <AxesSubplot: xlabel='State_name', ylabel='Population'>

# %%
df.plot(kind='box',x='State_name',y='Population',figsize=(6,6))
# Out:
# <AxesSubplot: >

# %%
df['Population'].sum()
# Out:
# 1210854977

# %%
df['Population'].mean()
# Out:
# 1891960.9015625

# %%
df['Population'].median()
# Out:
# 1557367.0

# %%
# import scipy
df['Population'].plot(kind='box',figsize=(14,6))
# Out:
# <AxesSubplot: >

# %%
df
# Out:
#                       State_name              District_name  Literate  \
# 0              JAMMU AND KASHMIR                    Kupwara    439654
# 1              JAMMU AND KASHMIR                     Badgam    335649
# 2              JAMMU AND KASHMIR                Leh(Ladakh)     93770
# 3              JAMMU AND KASHMIR                     Kargil     86236
# 4              JAMMU AND KASHMIR                      Punch    261724
# ..                           ...                        ...       ...
# 635                  PONDICHERRY                       Mahe     36470
# 636                  PONDICHERRY                   Karaikal    154916
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     25332
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman     78683
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman    190266
#
#      Female_Literate  Male_Literate  Population  Graduate_Education  \
# ...

# %% [markdown]
# # Number of Districts in Indian States

# %%
df['State_name'].value_counts()
# Out:
# UTTAR PRADESH                  71
# MADHYA PRADESH                 50
# BIHAR                          38
# MAHARASHTRA                    35
# RAJASTHAN                      33
# TAMIL NADU                     32
# KARNATAKA                      30
# ORISSA                         30
# ASSAM                          27
# GUJARAT                        26
# JHARKHAND                      24
# ANDHRA PRADESH                 23
# JAMMU AND KASHMIR              22
# HARYANA                        21
# PUNJAB                         20
# WEST BENGAL                    19
# CHHATTISGARH                   18
# ARUNACHAL PRADESH              16
# KERALA                         14
# UTTARAKHAND                    13
# HIMACHAL PRADESH               12
# NAGALAND                       11
# MANIPUR                         9
# NCT OF DELHI                    9
# MIZORAM                         8
# MEGHALAYA                       7
# TRIPURA                         4
# ...

# %%
df['State_name'].value_counts().plot(kind='pie',figsize=(6,6))
# Out:
# <AxesSubplot: ylabel='State_name'>

# %% [markdown]
# # Bivariant Analysis

# %%
df.columns
# Out:
# Index(['State_name', 'District_name', 'Literate', 'Female_Literate',
#        'Male_Literate', 'Population', 'Graduate_Education',
#        'Illiterate_Education'],
#       dtype='object')

# %%
sns.scatterplot(data=df,x='State_name',y='Literate')
# Out:
# <AxesSubplot: xlabel='State_name', ylabel='Literate'>

# %%
# df = df.drop('District_name',axis= 1)
sns.pairplot(df,hue='State_name')

# %% [markdown]
# # Population in state with literate Population

# %%
df.groupby(['State_name'])['Literate', 'Female_Literate',
       'Male_Literate', 'Population', 'Graduate_Education',
       'Illiterate_Education'].sum()
# Out:
#                               Literate  Female_Literate  Male_Literate  \
# State_name
# ANDAMAN AND NICOBAR ISLANDS     294281           129904         164377
# ANDHRA PRADESH                50556760         22305517       28251243
# ARUNACHAL PRADESH               766005           326137         439868
# ASSAM                         19177977          8609338       10568639
# BIHAR                         52504553         20896530       31608023
# CHANDIGARH                      805438           340092         465346
# CHHATTISGARH                  15379922          6572029        8807893
# DADRA AND NAGAR HAVELI          223230            80709         142521
# DAMAN AND DIU                   188406            63763         124643
# GOA                            1165487           549664         615823
# GUJARAT                       41093358         17618485       23474873
# HARYANA                       16598988          6804921        9794067
# ...

# %%
df.corr()
# Out:
#                       Literate  Female_Literate  Male_Literate  Population  \
# Literate              1.000000         0.995382       0.996968    0.972610
# Female_Literate       0.995382         1.000000       0.984896    0.951885
# Male_Literate         0.996968         0.984896       1.000000    0.982820
# Population            0.972610         0.951885       0.982820    1.000000
# Graduate_Education    0.873324         0.882389       0.860060    0.791776
# Illiterate_Education  0.659136         0.607470       0.696548    0.810283
#
#                       Graduate_Education  Illiterate_Education
# Literate                        0.873324              0.659136
# Female_Literate                 0.882389              0.607470
# Male_Literate                   0.860060              0.696548
# Population                      0.791776              0.810283
# Graduate_Education              1.000000              0.383366
# Illiterate_Education            0.383366              1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot: >
